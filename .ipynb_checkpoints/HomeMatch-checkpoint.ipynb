# %%
import getpass
import os

os.environ["OPENAI_API_BASE"] = "https://openai.vocareum.com/v1"

if "OPENAI_API_KEY" not in os.environ:
    os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API key: ")
# Out:
# Enter your OpenAI API key:  ········

# %%
from langchain_openai import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.schema import AIMessage, HumanMessage, SystemMessage
from langchain.memory import ConversationSummaryMemory, ConversationBufferMemory, CombinedMemory, ChatMessageHistory
from langchain.chains import ConversationChain
from langchain_community.document_loaders.csv_loader import CSVLoader
from langchain_openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain_chroma import Chroma
from langchain.chains.question_answering import load_qa_chain
from langchain.chains import RetrievalQA

# %%
model_name = "gpt-3.5-turbo"
temperature = 0.0
llm = ChatOpenAI(
    model=model_name,
    temperature=0,
    max_tokens=1024,
    max_retries=2
)

# %% [markdown]
# ## Step 2: Generating Real Estate Listings

# %%
system_prompt = "You are a helpful assistant that generates real estate listings"
human_prompt = """
Create 2 listings as CSV:
Listing Example:

Neighborhood: Green Oaks
Price: $800,000
Bedrooms: 3
Bathrooms: 2
House Size: 2,000 sqft

Description: Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.

Neighborhood Description: Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze.
"""

messages = [
    ("system", system_prompt),
    ("human", human_prompt),
]
ai_msg = llm.invoke(messages)
ai_msg.content
# Out:
# 'Neighborhood,Price,Bedrooms,Bathrooms,House Size,Description,Neighborhood Description\nGreen Oaks,$800,000,3,2,2000 sqft,"Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.","Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze."\nRiverfront Retreat,$1,200,000,4,3,3000 sqft,"Escape to this luxurious riverfront retreat offering breathtaking views and upscale living. This 4-bedroom, 3-bathroom home features high-end finishes, a gourmet kitchen with top-of-the-line appliances, and a spacious master suite with a private balcony overlooking the river. The expansive deck is perfect for entertaining guests or simply enjoying the serene waterfront setting. With a private dock for boating enthusiasts, this home is a true waterfront paradise.","Located in a serene riverside community, this neighborhood offers a peaceful escape from the hustle and bustle of city life. Enjoy water activities such as boating and fishing right from your backyard, or take a leisurely stroll along the riverbank. Close proximity to local dining options and boutique shops make this riverfront retreat the perfect blend of luxury and relaxation."'

# %% [markdown]
# ## Step 2.1: I generated the Real Estate Listings using the free version of ChatGPT 4o and put them in a listings.csv file for convenience

# %%
# Load CSV file using pandas for visualization purposes
import pandas as pd 

df = pd.read_csv("listings.csv")
df
# Out:
#         Neighborhood       Price  Bedrooms  Bathrooms  House Size  \
# 0      Sunny Meadows    $750,000         3          2  1,800 sqft
# 1        Cedar Grove    $850,000         4          3  2,200 sqft
# 2         Maple Park  $1,100,000         5          4  3,000 sqft
# 3         Pine Ridge    $900,000         4          3  2,400 sqft
# 4  Oceanview Estates  $1,500,000         4          3  2,800 sqft
# 5     Mountain Vista  $1,300,000         4          3  2,600 sqft
# 6         Green Oaks    $800,000         3          2  2,000 sqft
# 7       Sunset Ridge    $950,000         4          3  2,500 sqft
# 8   Lakeside Village  $1,200,000         5          4  3,200 sqft
# 9      Urban Heights    $650,000         2          2  1,400 sqft
#
#                                          Description  \
# 0  Enjoy suburban tranquility in this beautiful 3...
# 1  Step into luxury in this elegantly designed 4-...
# 2  Experience the grandeur of this spacious 5-bed...
# 3  This charming 4-bedroom, 3-bathroom home in Pi...
# 4  Welcome to Oceanview Estates, where luxury mee...
# 5  Set against the backdrop of stunning mountain ...
# 6  Welcome to this eco-friendly oasis nestled in ...
# 7  Experience luxury living at Sunset Ridge. This...
# 8  Discover lakeside elegance in this exquisite 5...
# 9  Welcome to Urban Heights, a chic and contempor...
#
#                             Neighborhood Description
# 0  Sunny Meadows is known for its friendly commun...
# 1  Cedar Grove is a vibrant neighborhood celebrat...
# 2  Maple Park boasts tree-lined streets, historic...
# 3  Pine Ridge is celebrated for its scenic beauty...
# 4  Oceanview Estates is a prestigious community o...
# 5  Mountain Vista is a picturesque community know...
# 6  Green Oaks is a close-knit, environmentally-co...
# 7  Sunset Ridge is an upscale neighborhood known ...
# 8  Lakeside Village is a vibrant community built ...
# 9  Urban Heights is located in the heart of the c...

# %% [markdown]
# ### Load CSV with CSVLoader

# %%
loader = CSVLoader(file_path="./listings.csv")
listings = loader.load()

# %% [markdown]
# ## Step 3: Storing Listings in a Vector Database

# %% [markdown]
# ### Step 3.1 Vector Database Setup:
# - Vector Database Setup: Initialize and configure ChromaDB or a similar vector database to store real estate listings.
# - Generating and Storing Embeddings: Convert the LLM-generated listings into suitable embeddings that capture the semantic content of each listing, and store these embeddings in the vector database.
#
# We will use a CharacterTextSplitter just for demonstration purposes

# %%
splitter = CharacterTextSplitter(chunk_size=500, chunk_overlap=0)
split_listings = splitter.split_documents(listings)

embeddings = OpenAIEmbeddings()

db = Chroma.from_documents(split_listings, embeddings)

# %%
# Checking the splits
for split in split_listings:
    print(split)
    print("\n")
# Out:
# page_content='Neighborhood: Sunny Meadows
# Price: $750,000
# Bedrooms: 3
# Bathrooms: 2
# House Size: 1,800 sqft
# Description: Enjoy suburban tranquility in this beautiful 3-bedroom home in Sunny Meadows. The house features an open layout, a modern kitchen with energy-efficient appliances, and a cozy living room filled with natural light. A well-manicured garden and spacious backyard provide the perfect space for family gatherings.
# Neighborhood Description: Sunny Meadows is known for its friendly community, lush parks, and top-rated schools. Residents enjoy a peaceful atmosphere with easy access to local amenities and shopping centers.' metadata={'source': './listings.csv', 'row': 0}
#
#
# page_content='Neighborhood: Cedar Grove
# Price: $850,000
# Bedrooms: 4
# Bathrooms: 3
# House Size: 2,200 sqft
# Description: Step into luxury in this elegantly designed 4-bedroom home in Cedar Grove. Featuring a gourmet kitchen, spacious bedrooms with ample closet space, and a master suite with a spa-inspired bath, this residence combines sophistication with comfort.
# Neighborhood Description: Cedar Grove is a vibrant neighborhood celebrated for its rich cultural heritage and thriving arts scene. Enjoy local festivals, charming cafes, and boutique shopping at every turn.' metadata={'source': './listings.csv', 'row': 1}
#
#
# page_content='Neighborhood: Maple Park
# Price: $1,100,000
# Bedrooms: 5
# Bathrooms: 4
# House Size: 3,000 sqft
# Description: Experience the grandeur of this spacious 5-bedroom, 4-bathroom home in Maple Park. Designed with a blend of traditional and modern aesthetics, the property features a grand foyer, high ceilings, and an expansive living area perfect for entertaining guests.
# Neighborhood Description: Maple Park boasts tree-lined streets, historic architecture, and a lively community spirit. Its central park and nearby cultural landmarks make it a desirable locale for families and professionals alike.' metadata={'source': './listings.csv', 'row': 2}
#
#
# page_content='Neighborhood: Pine Ridge
# Price: $900,000
# Bedrooms: 4
# Bathrooms: 3
# House Size: 2,400 sqft
# Description: This charming 4-bedroom, 3-bathroom home in Pine Ridge is a perfect blend of rustic charm and modern convenience. With an open-concept layout, hardwood floors, and a large backyard, this property offers both comfort and style.
# Neighborhood Description: Pine Ridge is celebrated for its scenic beauty, hiking trails, and a strong sense of community. The neighborhood features local farmers markets, community events, and a serene, rural atmosphere.' metadata={'source': './listings.csv', 'row': 3}
#
#
# page_content='Neighborhood: Oceanview Estates
# Price: $1,500,000
# Bedrooms: 4
# Bathrooms: 3
# House Size: 2,800 sqft
# Description: Welcome to Oceanview Estates, where luxury meets coastal living. This exquisite 4-bedroom, 3-bathroom property offers panoramic ocean views, a contemporary open layout, and high-end finishes throughout. Step outside to your private terrace and experience breathtaking sunsets.
# Neighborhood Description: Oceanview Estates is a prestigious community offering exclusive beach access, upscale dining, and boutique shopping. Residents enjoy a blend of coastal serenity and modern amenities in this highly sought-after neighborhood.' metadata={'source': './listings.csv', 'row': 4}
#
#
# page_content='Neighborhood: Mountain Vista
# Price: $1,300,000
# Bedrooms: 4
# Bathrooms: 3
# House Size: 2,600 sqft
# Description: Set against the backdrop of stunning mountain ranges, this 4-bedroom, 3-bathroom home in Mountain Vista offers a perfect retreat from the hustle and bustle. The home features a spacious living area, large windows capturing breathtaking views, and a modern kitchen designed for entertaining.
# Neighborhood Description: Mountain Vista is a picturesque community known for its outdoor recreational opportunities, including hiking, skiing, and nature trails. The neighborhood exudes a peaceful, nature-inspired vibe while providing easy access to modern conveniences.' metadata={'source': './listings.csv', 'row': 5}
#
#
# page_content='Neighborhood: Green Oaks
# Price: $800,000
# Bedrooms: 3
# Bathrooms: 2
# House Size: 2,000 sqft
# Description: Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.
# Neighborhood Description: Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze.' metadata={'source': './listings.csv', 'row': 6}
#
#
# page_content='Neighborhood: Sunset Ridge
# Price: $950,000
# Bedrooms: 4
# Bathrooms: 3
# House Size: 2,500 sqft
# Description: Experience luxury living at Sunset Ridge. This stunning 4-bedroom, 3-bathroom home offers modern amenities and breathtaking views of the sunset over rolling hills. The open-plan living and dining areas are perfect for entertaining, and the gourmet kitchen is a chef's delight. Relax in the spacious master suite with a spa-like bathroom and enjoy outdoor living on the expansive patio.
# Neighborhood Description: Sunset Ridge is an upscale neighborhood known for its serene atmosphere, scenic vistas, and active community lifestyle. Enjoy nearby parks, exclusive clubs, and gourmet dining options that cater to a refined taste in living.' metadata={'source': './listings.csv', 'row': 7}
#
#
# page_content='Neighborhood: Lakeside Village
# Price: $1,200,000
# Bedrooms: 5
# Bathrooms: 4
# House Size: 3,200 sqft
# Description: Discover lakeside elegance in this exquisite 5-bedroom, 4-bathroom residence located in the heart of Lakeside Village. The home boasts panoramic lake views, an open living space with high ceilings, and contemporary design elements. Enjoy a modern kitchen equipped with top-of-the-line appliances, a cozy fireplace, and an inviting outdoor deck perfect for relaxation and entertainment.
# Neighborhood Description: Lakeside Village is a vibrant community built around the natural beauty of its lake. With a rich array of water sports, walking trails, and lakeside dining, it offers an active, yet relaxed lifestyle in a picturesque setting.' metadata={'source': './listings.csv', 'row': 8}
#
#
# page_content='Neighborhood: Urban Heights
# Price: $650,000
# Bedrooms: 2
# Bathrooms: 2
# House Size: 1,400 sqft
# Description: Welcome to Urban Heights, a chic and contemporary home perfect for modern living. This stylish 2-bedroom, 2-bathroom condo offers sleek finishes, an open floor plan, and plenty of natural light. With a focus on urban convenience and comfort, this property features high-end appliances, smart home technology, and a balcony with city views.
# Neighborhood Description: Urban Heights is located in the heart of the city, surrounded by trendy cafes, boutique shops, and cultural hotspots. Enjoy a vibrant urban lifestyle with easy access to public transportation, nightlife, and modern amenities designed for the contemporary resident.' metadata={'source': './listings.csv', 'row': 9}

# %% [markdown]
# #### Testing the database

# %%
query = """
    List as bullet points the name of the neighborhoods with 4 bedroom houses. 
    explain the steps you took to get to this result
"""

use_chain_helper = False
if use_chain_helper:
    rag = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=db.as_retriever())
    print(rag.run(query))
else:
    similar_docs = db.similarity_search(query, k=5)
    # similar_docs = db.similarity_search_by_vector(embedding=embeddings.embed_query(query), k=5)
    # similar_docs = db.similarity_search_with_score(query, k=5)
    # Standard similarity search was returning overly similar results. 
    # Trying MMR to increase diversity:
    # similar_docs = db.max_marginal_relevance_search(query, k=5, fetch_k=50)
    
    for doc in similar_docs:
        print(doc.page_content)
        print("\n######")
    
    prompt = PromptTemplate(
        template="{query}\nContext: {context}",
        input_variables=["query", "context"],
    )
    chain = load_qa_chain(llm, prompt = prompt, chain_type="stuff")
    print(chain.run(input_documents=similar_docs, query = query))
# Out:
# Neighborhood: Oceanview Estates
# Price: $1,500,000
# Bedrooms: 4
# Bathrooms: 3
# House Size: 2,800 sqft
# Description: Welcome to Oceanview Estates, where luxury meets coastal living. This exquisite 4-bedroom, 3-bathroom property offers panoramic ocean views, a contemporary open layout, and high-end finishes throughout. Step outside to your private terrace and experience breathtaking sunsets.
# Neighborhood Description: Oceanview Estates is a prestigious community offering exclusive beach access, upscale dining, and boutique shopping. Residents enjoy a blend of coastal serenity and modern amenities in this highly sought-after neighborhood.
#
# ######
# Neighborhood: Mountain Vista
# Price: $1,300,000
# Bedrooms: 4
# Bathrooms: 3
# House Size: 2,600 sqft
# Description: Set against the backdrop of stunning mountain ranges, this 4-bedroom, 3-bathroom home in Mountain Vista offers a perfect retreat from the hustle and bustle. The home features a spacious living area, large windows capturing breathtaking views, and a modern kitchen designed for entertaining.
# Neighborhood Description: Mountain Vista is a picturesque community known for its outdoor recreational opportunities, including hiking, skiing, and nature trails. The neighborhood exudes a peaceful, nature-inspired vibe while providing easy access to modern conveniences.
#
# ######
# Neighborhood: Maple Park
# Price: $1,100,000
# Bedrooms: 5
# Bathrooms: 4
# House Size: 3,000 sqft
# Description: Experience the grandeur of this spacious 5-bedroom, 4-bathroom home in Maple Park. Designed with a blend of traditional and modern aesthetics, the property features a grand foyer, high ceilings, and an expansive living area perfect for entertaining guests.
# Neighborhood Description: Maple Park boasts tree-lined streets, historic architecture, and a lively community spirit. Its central park and nearby cultural landmarks make it a desirable locale for families and professionals alike.
#
# ######
# Neighborhood: Urban Heights
# Price: $650,000
# Bedrooms: 2
# Bathrooms: 2
# House Size: 1,400 sqft
# Description: Welcome to Urban Heights, a chic and contemporary home perfect for modern living. This stylish 2-bedroom, 2-bathroom condo offers sleek finishes, an open floor plan, and plenty of natural light. With a focus on urban convenience and comfort, this property features high-end appliances, smart home technology, and a balcony with city views.
# Neighborhood Description: Urban Heights is located in the heart of the city, surrounded by trendy cafes, boutique shops, and cultural hotspots. Enjoy a vibrant urban lifestyle with easy access to public transportation, nightlife, and modern amenities designed for the contemporary resident.
#
# ######
# Neighborhood: Cedar Grove
# Price: $850,000
# Bedrooms: 4
# Bathrooms: 3
# House Size: 2,200 sqft
# Description: Step into luxury in this elegantly designed 4-bedroom home in Cedar Grove. Featuring a gourmet kitchen, spacious bedrooms with ample closet space, and a master suite with a spa-inspired bath, this residence combines sophistication with comfort.
# Neighborhood Description: Cedar Grove is a vibrant neighborhood celebrated for its rich cultural heritage and thriving arts scene. Enjoy local festivals, charming cafes, and boutique shopping at every turn.
#
# ######
# - Oceanview Estates
# - Mountain Vista
# - Cedar Grove
#
# To determine the neighborhoods with 4 bedroom houses, I carefully read through the descriptions of each property provided. I specifically looked for the number of bedrooms listed for each neighborhood and identified those that had 4 bedroom houses. In this case, Oceanview Estates, Mountain Vista, and Cedar Grove were the neighborhoods that had 4 bedroom houses.

# %% [markdown]
# ## Step 4: Building the User Preference Interface

# %%
questions = [   
                "How big do you want your house to be?" 
                "What are 3 most important things for you in choosing this property?", 
                "Which amenities would you like?", 
                "Which transportation options are important to you?",
                "How urban do you want your neighborhood to be?",   
            ]
answers = [
    "A comfortable three-bedroom house with a spacious kitchen and a cozy living room.",
    "A quiet neighborhood, good local schools, and convenient shopping options.",
    "A backyard for gardening, a two-car garage, and a modern, energy-efficient heating system.",
    "Easy access to a reliable bus line, proximity to a major highway, and bike-friendly roads.",
    "A balance between suburban tranquility and access to urban amenities like restaurants and theaters."
]

# %%
# hard-coding buyer preference for convenience
buyer_preferences = answers[0]
buyer_preferences
# Out:
# 'A comfortable three-bedroom house with a spacious kitchen and a cozy living room.'

# %% [markdown]
# ### Step 5: Searching Based on Preferences
#
# Semantic Search Implementation: Use the structured buyer preferences to perform a semantic search on the vector database, retrieving listings that most closely match the user's requirements.
# Listing Retrieval Logic: Fine-tune the retrieval algorithm to ensure that the most relevant listings are selected based on the semantic closeness to the buyer’s preferences.

# %%
# Standard similarity search was returning overly similar results. 
# Trying MMR to increase diversity:
similar_docs = db.similarity_search(query, k=5)

print(f"Buyers preference: \n{buyer_preferences}")
# Out:
# Buyers preference:
# A comfortable three-bedroom house with a spacious kitchen and a cozy living room.

# %% [markdown]
# ### Step 6: Personalizing Listing Descriptions
# LLM Augmentation: For each retrieved listing, use the LLM to augment the description, tailoring it to resonate with the buyer’s specific preferences. This involves subtly emphasizing aspects of the property that align with what the buyer is looking for.
# Maintaining Factual Integrity: Ensure that the augmentation process enhances the appeal of the listing without altering factual information.

# %%
query = """
Using the details from the property listing provided in the context, 
generate an enhanced description that speaks directly to the buyer's unique preferences. 

Tailor the language to emphasize features of the properties such as design elements, 
amenities, or neighborhood benefits—that align with what the buyer is looking for. 
While augmenting the description to increase its appeal, 
ensure that all factual information (like price, number of bedrooms, bathrooms, and square footage) remains unchanged.
""" 

for doc in similar_docs:
    print("\n__Listing:\n")
    print(doc.page_content)
    prompt = PromptTemplate(
        template="{query}\nContext: {context}",
        input_variables=["query", "context"],
    )

    chain = load_qa_chain(llm, prompt = prompt, chain_type="stuff")
    print("\n__LLM Augmentation:\n")
    print(chain.run(input_documents=[doc], query = query))
    print("\n------------------------------------------------")
# Out:
# __Listing:
#
# Neighborhood: Oceanview Estates
# Price: $1,500,000
# Bedrooms: 4
# Bathrooms: 3
# House Size: 2,800 sqft
# Description: Welcome to Oceanview Estates, where luxury meets coastal living. This exquisite 4-bedroom, 3-bathroom property offers panoramic ocean views, a contemporary open layout, and high-end finishes throughout. Step outside to your private terrace and experience breathtaking sunsets.
# Neighborhood Description: Oceanview Estates is a prestigious community offering exclusive beach access, upscale dining, and boutique shopping. Residents enjoy a blend of coastal serenity and modern amenities in this highly sought-after neighborhood.
#
# __LLM Augmentation:
#
# Step into your dream coastal oasis at Oceanview Estates, where luxury and breathtaking ocean views await. This stunning 4-bedroom, 3-bathroom home boasts a contemporary open layout, high-end finishes, and a private terrace perfect for enjoying stunning sunsets.
#
# Located in the prestigious Oceanview Estates community, you'll have exclusive beach access, upscale dining options, and boutique shopping right at your fingertips. Embrace the perfect blend of coastal serenity and modern amenities in this highly sought-after neighborhood. Don't miss out on the opportunity to make this coastal paradise your own for $1,500,000.
#
# ------------------------------------------------
#
# __Listing:
#
# Neighborhood: Mountain Vista
# Price: $1,300,000
# Bedrooms: 4
# Bathrooms: 3
# House Size: 2,600 sqft
# Description: Set against the backdrop of stunning mountain ranges, this 4-bedroom, 3-bathroom home in Mountain Vista offers a perfect retreat from the hustle and bustle. The home features a spacious living area, large windows capturing breathtaking views, and a modern kitchen designed for entertaining.
# Neighborhood Description: Mountain Vista is a picturesque community known for its outdoor recreational opportunities, including hiking, skiing, and nature trails. The neighborhood exudes a peaceful, nature-inspired vibe while providing easy access to modern conveniences.
#
# __LLM Augmentation:
#
# Escape to your own mountain oasis in the serene community of Mountain Vista. This 4-bedroom, 3-bathroom home is a sanctuary of modern design and natural beauty. With a spacious living area, large windows framing panoramic mountain views, and a sleek kitchen perfect for hosting gatherings, this home is a true gem.
#
# Located in a neighborhood renowned for its outdoor adventures, Mountain Vista offers hiking, skiing, and nature trails right at your doorstep. Embrace the tranquil, nature-inspired atmosphere while still enjoying the convenience of nearby amenities. Priced at $1,300,000, this 2,600 sqft home is the perfect blend of luxury and nature, waiting for you to make it your own.
#
# ------------------------------------------------
#
# __Listing:
#
# Neighborhood: Maple Park
# Price: $1,100,000
# Bedrooms: 5
# Bathrooms: 4
# House Size: 3,000 sqft
# Description: Experience the grandeur of this spacious 5-bedroom, 4-bathroom home in Maple Park. Designed with a blend of traditional and modern aesthetics, the property features a grand foyer, high ceilings, and an expansive living area perfect for entertaining guests.
# Neighborhood Description: Maple Park boasts tree-lined streets, historic architecture, and a lively community spirit. Its central park and nearby cultural landmarks make it a desirable locale for families and professionals alike.
#
# __LLM Augmentation:
#
# Indulge in the luxurious charm of this exquisite 5-bedroom, 4-bathroom home nestled in the heart of Maple Park. Boasting a seamless fusion of traditional elegance and contemporary design, this property offers a grand foyer, soaring ceilings, and a sprawling living space ideal for hosting gatherings with style.
#
# Immerse yourself in the allure of Maple Park's picturesque tree-lined streets, rich historical architecture, and vibrant community ambiance. With a central park just steps away and a plethora of cultural attractions nearby, this neighborhood is a haven for families and professionals seeking a harmonious blend of serenity and convenience.
#
# Don't miss the opportunity to make this sophisticated residence your own and experience the epitome of refined living in Maple Park.
#
# ------------------------------------------------
#
# __Listing:
#
# Neighborhood: Urban Heights
# Price: $650,000
# Bedrooms: 2
# Bathrooms: 2
# House Size: 1,400 sqft
# Description: Welcome to Urban Heights, a chic and contemporary home perfect for modern living. This stylish 2-bedroom, 2-bathroom condo offers sleek finishes, an open floor plan, and plenty of natural light. With a focus on urban convenience and comfort, this property features high-end appliances, smart home technology, and a balcony with city views.
# Neighborhood Description: Urban Heights is located in the heart of the city, surrounded by trendy cafes, boutique shops, and cultural hotspots. Enjoy a vibrant urban lifestyle with easy access to public transportation, nightlife, and modern amenities designed for the contemporary resident.
#
# __LLM Augmentation:
#
# Step into your urban oasis at Urban Heights, where modern luxury meets city living. This 2-bedroom, 2-bathroom condo boasts a sleek design with high-end finishes and an open layout that maximizes natural light. Imagine cooking in your gourmet kitchen equipped with top-of-the-line appliances, or relaxing on your private balcony with stunning city views.
#
# Located in the bustling Urban Heights neighborhood, you'll be steps away from trendy cafes, boutique shops, and cultural attractions. Embrace the vibrant urban lifestyle with easy access to public transportation, nightlife, and modern amenities tailored for the contemporary resident. Don't miss out on the opportunity to make this chic and stylish home yours for $650,000. Live the urban dream at Urban Heights.
#
# ------------------------------------------------
#
# __Listing:
#
# Neighborhood: Cedar Grove
# Price: $850,000
# Bedrooms: 4
# Bathrooms: 3
# House Size: 2,200 sqft
# Description: Step into luxury in this elegantly designed 4-bedroom home in Cedar Grove. Featuring a gourmet kitchen, spacious bedrooms with ample closet space, and a master suite with a spa-inspired bath, this residence combines sophistication with comfort.
# Neighborhood Description: Cedar Grove is a vibrant neighborhood celebrated for its rich cultural heritage and thriving arts scene. Enjoy local festivals, charming cafes, and boutique shopping at every turn.
#
# __LLM Augmentation:
#
# Indulge in the epitome of luxury living with this stunning 4-bedroom home nestled in the heart of Cedar Grove. The gourmet kitchen is a chef's dream, perfect for hosting intimate gatherings or preparing culinary masterpieces. Each bedroom offers a sanctuary of comfort, complete with generous closet space for all your storage needs. The master suite is a true oasis, boasting a spa-inspired bath that promises relaxation and rejuvenation after a long day.
#
# Beyond the walls of this exquisite home lies the vibrant neighborhood of Cedar Grove, where cultural heritage and artistic expression converge. Immerse yourself in the local festivals that bring the community together, savor the flavors of charming cafes, and explore the unique finds at boutique shops just steps away. Embrace the lifestyle you've always dreamed of in this captivating enclave of sophistication and charm. Welcome home to Cedar Grove.
#
# ------------------------------------------------
